# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeRodziewicz/Udemy_ML_Bootcamp/blob/main/data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
fig.show()

# %%
_ = plt.plot([0,10],[0,10], label='line', color='green')
plt.legend()

# %%
x = np.arange(-3,3,0.1)
x_sin = np.sin(x)

plt.plot(x, x_sin)
